# %%
# import shapefile
# shape = shapefile.Reader("City_Council_Districts_-_Effective_for_the_2023_Municipal_Election/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.shp")

import geopandas as gpd
gdf = gpd.read_file("City_Council_Districts_-_Effective_for_the_2023_Municipal_Election/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.shp")
print(gdf.head())
# Out:
#    FID    LONGNAME SHORTNAME  DISTRICT      COLOR  TOTAL  TARGET_DEV  \
# 0    1  District 1        D1         1 -851848832  76830        1758
# 1    2  District 2        D2         2  465990528  77466        2394
# 2    3  District 3        D3         3  494969216  73285       -1787
# 3    4  District 4        D4         4     -65408  72917       -2155
# 4    5  District 5        D5         5  412292224  75436         364
#
#    TARGET_D_1  TOTAL18  TOTALHISP  ...  BLACK  AIAN  ASIAN  HPI  OTHER  MLTMN  \
# 0        2.34    64257      24552  ...   3637   783   5080   50  20935   1689
# 1        3.19    70183       6640  ...   4520   269  13604   55   4893   1005
# 2       -2.38    60834      11898  ...  14990   492  13190   45   9927   5357
# 3       -2.87    54939      17409  ...  40030   653   3093   44  11569   7013
# 4        0.48    59652      18191  ...  35584   475   2022   42  12727   4194
#
#    Shape__Are  Shape__Len  DistrictTe  \
# 0    0.002985    0.380208           1
# 1    0.001969    0.341635           2
# 2    0.011007    0.957769           3
# 3    0.001324    0.296487           4
# 4    0.002300    0.313325           5
#
#                                             geometry
# 0  POLYGON ((-71.06406 42.36901, -71.06413 42.369...
# 1  POLYGON ((-71.07307 42.35125, -71.07194 42.351...
# 2  POLYGON ((-71.04935 42.33035, -71.04891 42.330...
# 3  POLYGON ((-71.08390 42.30760, -71.08369 42.307...
# 4  POLYGON ((-71.08546 42.28105, -71.08543 42.281...
#
# [5 rows x 38 columns]

# %%
type(gdf)
#the data type is GeoDataFrame
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# %matplotlib inline
gdf.plot()
#boston map divided by districts
# Out:
# <AxesSubplot: >

# %%
print(gdf.columns)
# Out:
# Index(['FID', 'LONGNAME', 'SHORTNAME', 'DISTRICT', 'COLOR', 'TOTAL',
#        'TARGET_DEV', 'TARGET_D_1', 'TOTAL18', 'TOTALHISP', 'TOTALNH',
#        'WHITENH', 'BLACKNH', 'AIANNH', 'ASIANNH', 'HPINH', 'OTHERNH',
#        'MLTMNNH', 'HISP18', 'NONHISP18', 'WHITENH18', 'BLACKNH18', 'AIANNH18',
#        'ASIANNH18', 'HPINH18', 'OTHERNH18', 'MLTMNNH18', 'WHITE', 'BLACK',
#        'AIAN', 'ASIAN', 'HPI', 'OTHER', 'MLTMN', 'Shape__Are', 'Shape__Len',
#        'DistrictTe', 'geometry'],
#       dtype='object')

# %%
gdf.geometry.name
# Out:
# 'geometry'

# %%
gdf.plot(column='TOTAL')
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)

gdf.plot(column='TOTAL', ax=ax, legend=True)
# Out:
# <AxesSubplot: >

# %%
d4 = gdf.loc[[4],'geometry']
d4.plot()
# Out:
# <AxesSubplot: >

# %%
# newdata = gdf.overlay(d4, how='intersection')
# newdata.plot()
#gdf.plot(color=gdf['COLOR'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 # newdata = gdf.overlay(d4, how='intersection')
#       2 # newdata.plot()
# ----> 3 gdf.plot(color=gdf['COLOR'])
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/geopandas/plotting.py:704, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     701     markersize = df[markersize].values
#     703 if column is None:
# --> 704     return plot_series(
#     705         df.geometry,
#     706         cmap=cmap,
#     707         color=color,
#     708         ax=ax,
#     709         figsize=figsize,
#     710         markersize=markersize,
#     711         aspect=aspect,
#     712         **style_kwds,
#     713     )
#     715 # To accept pd.Series and np.arrays as column
#     716 if isinstance(column, (np.ndarray, pd.Series)):
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/geopandas/plotting.py:458, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     455         facecolor = color_
#     457     values_ = values[poly_idx] if cmap else None
# --> 458     _plot_polygon_collection(
#     459         ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     460     )
#     462 # plot all LineStrings and MultiLineString components in same collection
#     463 lines = expl_series[line_idx]
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/geopandas/plotting.py:174, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     170     kwargs["color"] = color
#     172 _expand_kwargs(kwargs, multiindex)
# --> 174 collection = PatchCollection(
#     175     [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     176 )
#     178 if values is not None:
#     179     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/collections.py:1821, in PatchCollection.__init__(self, patches, match_original, **kwargs)
#    1818     kwargs['linestyles'] = [p.get_linestyle() for p in patches]
#    1819     kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
# -> 1821 super().__init__(**kwargs)
#    1823 self.set_paths(patches)
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/collections.py:202, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     199 self._offset_transform = offset_transform
#     201 self._path_effects = None
# --> 202 self._internal_update(kwargs)
#     203 self._paths = None
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/artist.py:1186, in Artist._internal_update(self, kwargs)
#    1179 def _internal_update(self, kwargs):
#    1180     """
#    1181     Update artist properties without prenormalizing them, but generating
#    1182     errors as if calling `set`.
#    1183
#    1184     The lack of prenormalization is to maintain backcompatibility.
#    1185     """
# -> 1186     return self._update_props(
#    1187         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1188         "{prop_name!r}")
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/artist.py:1162, in Artist._update_props(self, props, errfmt)
#    1159             if not callable(func):
#    1160                 raise AttributeError(
#    1161                     errfmt.format(cls=type(self), prop_name=k))
# -> 1162             ret.append(func(v))
#    1163 if ret:
#    1164     self.pchanged()
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/collections.py:755, in Collection.set_facecolor(self, c)
#     753     c = c.lower()
#     754 self._original_facecolor = c
# --> 755 self._set_facecolor(c)
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/collections.py:737, in Collection._set_facecolor(self, c)
#     734 if c is None:
#     735     c = self._get_default_facecolor()
# --> 737 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     738 self.stale = True
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/colors.py:487, in to_rgba_array(c, alpha)
#     485         rgba = np.array([to_rgba(cc) for cc in c])
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#     490     rgba[:, 3] = alpha
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/colors.py:487, in <listcomp>(.0)
#     485         rgba = np.array([to_rgba(cc) for cc in c])
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#     490     rgba[:, 3] = alpha
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/colors.py:299, in to_rgba(c, alpha)
#     297     rgba = None
#     298 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 299     rgba = _to_rgba_no_colorcycle(c, alpha)
#     300     try:
#     301         _colors_full_map.cache[c, alpha] = rgba
#
# File /opt/anaconda3/envs/CS506/lib/python3.10/site-packages/matplotlib/colors.py:381, in _to_rgba_no_colorcycle(c, alpha)
#     379 # tuple color.
#     380 if not np.iterable(c):
# --> 381     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     382 if len(c) not in [3, 4]:
#     383     raise ValueError("RGBA sequence should have length 3 or 4")
#
# ValueError: Invalid RGBA argument: -851848832
