# %%
import pandas as pd


data = pd.read_csv('../../../data/parks.csv')

# %%
print(data['Location'].unique())
# Out:
# ['Dorchester' 'Hyde Park' 'East Boston' 'South Boston' 'Fenway/Longwood'
#  'Roxbury' 'West Roxbury' 'Back Bay/Beacon Hill' 'Jamaica Plain'
#  'Charlestown' 'Allston-Brighton' 'Central Boston' 'Mattapan' 'Roslindale'
#  'Mission Hill' 'South End']

# %%
import matplotlib.pyplot as plt

#plt.figure(figsize=(30,30))
plt.bar(data['Location'].unique(),data.groupby('Location')['Park'].count())
plt.title('No of Parks per location', fontsize=20)
plt.xlabel('Location', fontsize=15)
plt.ylabel('Count of Parks', fontsize=15)
plt.xticks(rotation=90)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')

# Strip leading and trailing spaces from 'features' column
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Group by 'features' and get counts
park_counts = df.groupby('features')['Park'].count()
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature', fontsize=20)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Filter the dataframe by the Location column to get the parks in South Boston
d4Dor_df = df[df['Location'] == 'Dorchester'] 

#or (df['Location'] == 'Mattapan') or (df['Location'] == 'Roslindale') or (df['Location'] == 'Jamaica Plain')
# Group by the features column and count the number of parks
park_counts = d4Dor_df.groupby('features').size()

# Plot the bar chart
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature in Dorchester (C11)', fontsize=15)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Filter the dataframe by the Location column to get the parks in South Boston
d4Mat_df = df[df['Location'] == 'Mattapan'] 

#(df['Location'] == 'Roslindale') or (df['Location'] == 'Jamaica Plain')
# Group by the features column and count the number of parks
park_counts = d4Mat_df.groupby('features').size()

# Plot the bar chart
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature in Mattapan (B3)', fontsize=15)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Filter the dataframe by the Location column to get the parks in South Boston
d4Ros_df = df[df['Location'] == 'Roslindale'] 

#(df['Location'] == 'Jamaica Plain')
# Group by the features column and count the number of parks
park_counts = d4Ros_df.groupby('features').size()

# Plot the bar chart
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature in Roslindale (E5)', fontsize=15)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Filter the dataframe by the Location column to get the parks in South Boston
d4JP_df = df[df['Location'] == 'Jamaica Plain'] 

# Group by the features column and count the number of parks
park_counts = d4JP_df.groupby('features').size()

# Plot the bar chart
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature in Jamaica Plain (E13)', fontsize=15)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../../data/parks.csv')
df['features'] = df['Feature(s)'].str.split(',')
df['features'] = df['features'].apply(lambda x: [f.strip() for f in x])
df = df.explode('features')

# Filter the dataframe by the Location column to get the parks in South Boston
d4JP_df = df[df['Location'] == 'Roxbury'] 

# Group by the features column and count the number of parks
park_counts = d4JP_df.groupby('features').size()

# Plot the bar chart
park_counts.plot(kind='bar')

# Set the plot title and axis labels
plt.title('Number of Parks per Feature in Roxbury (B2)', fontsize=15)
plt.xlabel('Feature', fontsize=15)
plt.ylabel('Number of Parks', fontsize=15)

# Display the plot
plt.show()
