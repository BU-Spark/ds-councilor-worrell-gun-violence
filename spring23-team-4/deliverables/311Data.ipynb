# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/311.csv')
df['TYPE'].unique()
# Out:
# array(['Animal Found', 'Animal Generic Request', 'Animal Lost',
#        'Empty Litter Basket', 'General Comments For a Program or Policy',
#        'General Request', 'Graffiti Removal', 'Ground Maintenance',
#        'Heat - Excessive, Insufficient', 'HP Sign', 'Illegal Dumping',
#        'Illegal Rooming House', 'Maintenance Complaint - Residential',
#        'Metrolist Client Intake Form',
#        'Missed Trash/Recycling/Yard Waste/Bulk Item', 'Notification',
#        'Parking Enforcement', 'Pick up Dead Animal',
#        'Request for Pothole Repair',
#        'Request for Snow Plowing (Emergency Responder)',
#        'Requests for Street Cleaning', 'Schedule a Bulk Item Pickup',
#        'Schedule a Bulk Item Pickup SS', 'Sign Repair', 'Sticker Request',
#        'Street Light Outages', 'Traffic Signal Repair',
#        'Unsatisfactory Living Conditions', 'Utility Call-In',
#        'Utility Casting Repair', 'Watermain Break', 'Abandoned Vehicles',
# ...
