# %% [markdown]
# ## Offenses in Boston

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from folium import Marker, Map, Circle, Icon
from folium.plugins import HeatMap

# %%
offensesDF = pd.read_csv("data/offenses.csv")
print(offensesDF.shape)
# Out:
# (73852, 17)
# C:\Users\marce\AppData\Local\Temp/ipykernel_11368/2401630367.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   offensesDF = pd.read_csv("data/offenses.csv")

# %%
offensesDF['OFFENSE_CODE'] = offensesDF['OFFENSE_CODE'].astype(str)

list_offenses = [613, 612, 615, 111, 242, 254, 271, 244, 251, 243, 261, 252, 253, 301, 361, 381, 801, 802, 423, 413, 724, 727, 706,
                 541, 540, 562, 561, 542, 521, 520, 522, 560, 1825, 1815, 1832, 1831, 2609, 1810, 1830, 1501, 1503, 1502, 1504, 1510, 121,
                 222, 230, 236, 211, 232, 233, 224, 213, 223, 231, 237, 212, 234, 235, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311,
                 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 
                 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 
                 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 616, 626, 636, 618, 628, 638,
                 617, 627, 637, 614, 624, 634, 619, 629, 639, 621, 611, 631, 612, 622, 632, 613, 623, 633, 615, 625, 635, 649, 1870, 2609, 1874,
                1842, 1841, 1849, 1848, 1858, 1855, 1864, 1863, 1866, 1868, 1843, 3023, 3021, 1875, 3022, 1847, 1840, 1873, 3017, 3016, 1501, 3119,
                3203, 3204, 1503, 1502, 1844, 1843, 1845, 1846, 1870, 1874, 1842, 1841, 1849, 3119, 1847, 1848, 1850, 1805, 1806]

list_string = map(str, list_offenses)

filtered_offenses = offensesDF[offensesDF['OFFENSE_CODE'].isin(list_string)]

filtered_offenses = filtered_offenses.dropna(subset=['Lat', 'Long'])
print(filtered_offenses.shape)
# Out:
# (23088, 17)

# %% [markdown]
# ## All Offenses

# %%
import folium
from geopy import Nominatim

# create a map object
m = folium.Map(location=[42.291721284828014, -71.07597990028424], zoom_start=13)

filtered_offenses['Lat'] = filtered_offenses['Lat'].astype(float)
filtered_offenses['Long'] = filtered_offenses['Long'].astype(float)

HeatMap(filtered_offenses[['Lat', 'Long']]).add_to(m)


folium.GeoJson('City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.geojson',
               name='geojson').add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("All_offenses.html")

# %% [markdown]
# ## Theft including larceny

# %%
offensesDF = pd.read_csv("data/offenses.csv")
offensesDF['OFFENSE_CODE'] = offensesDF['OFFENSE_CODE'].astype(str)

list_offenses_theft = [723,724,724,727,706,706,735,780,770,790,727,714,715,712,711,713,704,702,701,541, 540, 542, 561, 560, 562, 521, 520, 522,
                       619, 616, 626, 636, 618, 628, 638, 617, 627, 637, 649, 614, 624, 634, 619, 629, 639, 611, 611, 621, 631, 612, 612, 622, 632, 613, 613, 623, 633, 617, 618, 614, 616, 615, 615, 625, 635,
                       1300]

list_string = map(str, list_offenses_theft)

filtered_offenses_theft = offensesDF[offensesDF['OFFENSE_CODE'].isin(list_string)]

filtered_offenses_theft = filtered_offenses_theft.dropna(subset=['Lat', 'Long'])
print(filtered_offenses_theft.shape)
# Out:
# (10495, 17)
# C:\Users\marce\AppData\Local\Temp/ipykernel_11368/3996845599.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   offensesDF = pd.read_csv("data/offenses.csv")

# %%
# create a map object
m_theft = folium.Map(location=[42.291721284828014, -71.07597990028424], zoom_start=13)

filtered_offenses_theft['Lat'] = filtered_offenses_theft['Lat'].astype(float)
filtered_offenses_theft['Long'] = filtered_offenses_theft['Long'].astype(float)

HeatMap(filtered_offenses_theft[['Lat', 'Long']]).add_to(m_theft)


folium.GeoJson('City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.geojson',
               name='geojson').add_to(m_theft)

# display the map
m_theft
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_theft.save("theft_offenses.html")

# %% [markdown]
# ## Firearm Activity (Shootings + Illegal Carry)

# %%
offensesDF = pd.read_csv("data/offenses.csv")
offensesDF['OFFENSE_CODE'] = offensesDF['OFFENSE_CODE'].astype(str)

list_offenses_firearm = [401, 402, 411, 431, 3017, 3016, 3016, 1501, 3119, 3119, 3203, 3203, 3204, 1503, 1502, 305, 301, 302, 303, 304, 306, 307, 308,
                         341, 342, 343, 344, 345, 346, 347, 348, 1501, 1510, 1502]

list_string = map(str, list_offenses_firearm)

filtered_offenses_firearm = offensesDF[offensesDF['OFFENSE_CODE'].isin(list_string)]

filtered_offenses_firearm = filtered_offenses_firearm.dropna(subset=['Lat', 'Long'])
print(filtered_offenses_firearm.shape)
# Out:
# (1137, 17)
# C:\Users\marce\AppData\Local\Temp/ipykernel_11368/2927038631.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   offensesDF = pd.read_csv("data/offenses.csv")

# %%
# create a map object
m_firearm = folium.Map(location=[42.291721284828014, -71.07597990028424], zoom_start=13)

filtered_offenses_firearm['Lat'] = filtered_offenses_firearm['Lat'].astype(float)
filtered_offenses_firearm['Long'] = filtered_offenses_firearm['Long'].astype(float)

HeatMap(filtered_offenses_firearm[['Lat', 'Long']]).add_to(m_firearm)


folium.GeoJson('City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.geojson',
               name='geojson').add_to(m_firearm)

# display the map
m_firearm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_firearm.save("firearm_offenses.html")

# %% [markdown]
# ## Drug related incidents

# %%
offensesDF = pd.read_csv("data/offenses.csv")
offensesDF['OFFENSE_CODE'] = offensesDF['OFFENSE_CODE'].astype(str)

list_offenses_drug = [1805, 1806, 1807, 1870, 1870, 2609, 2609, 1874, 1874, 1858, 1842, 1842, 1841, 1841, 1849, 1849, 1848, 
                      1843, 1844, 1855, 1847, 1845, 1864, 1848, 1863, 1846, 1850, 1866, 1868, 1815, 1825, 1843, 1810, 3023, 
                      1830, 3021, 1875, 1832, 1831, 3022, 1847, 1840, 1873, 2102]

list_string = map(str, list_offenses_drug)

filtered_offenses_drug = offensesDF[offensesDF['OFFENSE_CODE'].isin(list_string)]

filtered_offenses_drug = filtered_offenses_drug.dropna(subset=['Lat', 'Long'])
print(filtered_offenses_drug.shape)
# Out:
# (7429, 17)
# C:\Users\marce\AppData\Local\Temp/ipykernel_11368/3578469158.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   offensesDF = pd.read_csv("data/offenses.csv")

# %%
# create a map object
m_drug = folium.Map(location=[42.291721284828014, -71.07597990028424], zoom_start=13)

filtered_offenses_drug['Lat'] = filtered_offenses_drug['Lat'].astype(float)
filtered_offenses_drug['Long'] = filtered_offenses_drug['Long'].astype(float)

HeatMap(filtered_offenses_drug[['Lat', 'Long']]).add_to(m_drug)


folium.GeoJson('City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.geojson',
               name='geojson').add_to(m_drug)

# display the map
m_drug
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m_drug.save("drug_offenses.html")
